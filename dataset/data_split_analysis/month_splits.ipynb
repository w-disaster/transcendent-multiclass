# %% [markdown]
# # Analyze data split using 80-20 Balancing score, Jensen-Shannon distance, % Appearing families

# %% [markdown]
# ## Setup the data frame and define the functions

# %%
from src.data_splits.utils.best_split_utils import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Get the merged malware data
df = pd.read_csv("../vt_reports/merge.csv")
df.head()
# Out:
#                                               sha256  first_submission_date
# 0  98f8e26e12b978102fa39c197f300ebe5fe535617737d5...             1630575593  \
# 1  7b2999ffadbc3b5b5c5e94145ca4e2f8de66ac1e3ddd52...             1629375559
# 2  e7569d494fe00be04ef6c9fcc5e54720c0df623b08e79d...             1362057319
# 3  1ed60c04f572b6acb9f64c31db55ef5c6b5465bd4da1eb...             1630624233
# 4  4c4aaff20a57213d9a786e56ad22f1eaa94694a2f1042b...             1592186154
#
#      family
# 0     tnega
# 1    quasar
# 2     pasta
# 3    cjishu
# 4  kingsoft

# %%
fsd = "first_submission_date"
# Convert the timestamps to datetime format
df_dt = df.copy()
df_dt[fsd] = df_dt[fsd].apply(lambda t: pd.to_datetime(t, unit='s'))

# %% [markdown]
# ## Compute the scores using the first day of each month as data splits

# %%
# Min and maximum dates
date_min = df_dt[fsd].min()
date_max = df_dt[fsd].max()

date_min_n = pd.Timestamp(f"{date_min.year}-{date_min.month}-{date_min.day}")
date_max_n = pd.Timestamp(f"{date_max.year}-{date_max.month}-{date_max.day}")

# Create 1-month equidistant splits
# "MS": use the Start of each Month from the minimum date to the maximum
date_splits = pd.date_range(start=date_min_n, end=date_max_n, freq="MS").tolist()

# %%
bs_f = lambda x: ((np.exp(-np.power(x - 0.7, 2)) - np.exp(-np.power(0.7, 2))) / 
                  (1 - np.exp(- np.power(0.7, 2))))

# %%
df_scores, df_ref_scores = df_dt.copy(), df_dt.copy()
js_scores, perc_app_families, balance_scores = [], [], []
for date_split in date_splits:
    scores = compute_scores(df=df_scores, ref_df=df_ref_scores, date_split=date_split, bs_f=bs_f)
    js_scores.append(scores["js"])
    perc_app_families.append(scores["af"])
    balance_scores.append(scores["bs"])

# %% [markdown]
# ## Plot the 80-20 Balancing score between train and test set
#
# As shown below, the highest balancing score is achieved using 2021-12-01 as the timestamp split.
# However, very few number of families are introduced in the test set (9 families, 1.34%). We further investigate the data on the latest years when there's both an increase and peak of $BS$ to see if we can choose a point where the number of appearing families is higher.

# %%
max_bs, idx_max_bs = np.max(balance_scores), np.argmax(balance_scores)

max_bs_split = date_splits[idx_max_bs]
print(f"Max balance score {max_bs}")
print_statistics(df_scores, max_bs_split, f"Best split based on Balance score at: {max_bs_split}")

df_bs = pd.DataFrame({"split": date_splits, "score": balance_scores})
plt.figure(figsize=(10, 7))
ax = sns.barplot(data=df_bs, x="split", y="score")

plt.title("80-20 training/testing Balance Score")
plt.xticks([])
plt.show()
# Out:
# Max balance score 0.9994940780933118
# ------------------------------------------------------------------
# Report: Best split based on Balance score at: 2021-12-01 00:00:00
# 	Training set length: 45962, (68.6%)
# 	Testing set length: 21038, (31.4%)
# 	Num families in training: 661
# 	Num families in testing: 611
# 	Common families: 602
# 	Families in training but not in testing: 59 (8.81%)
# 	Families in testing but not in training: 9 (1.34%)

# %% [markdown]
# ## Score focus
#
# From later on, the analysis will focus on the latest years, where there's both an increase and peak of $BS$.
# Splits at and after 2021-07-01 are considered, where the $BS > 0.5$.
#
# ### Observations
#
# - Choosing $BS > 0.5$ implies initiating with a basis comprising 40.18% of the training set length;
# - In 2021-08 lots of samples are submitted: at split 2021-08-01 the training length in percentage is 40.92%, and at 2021-09-01 it's 60.93%. In the first case 74 (11.04%) of new families are introduced, 16 in the second (2.39%);
# - At 2021-09-01 16 families are introduced in the test set as opposed to 9 of the subsequent three splits, while having 60.93% as training set length;
# - From 2021-10-01 to 2021-12-01 (included), the number of appearing families remain stable at 9 (as described before), while the training set length goes from 67.84% to 68.6%;
# - In the last three splits (from 2022-01-01) there isn't any new appearing family. Those splits are not interesting to study family drift, so they will be not considered;

# %%
plt.figure(figsize=(10, 7))

df_bs_focus = df_bs[df_bs["score"] > 0.5]
t_focus = df_bs_focus["split"].min()

ax = sns.barplot(data=df_bs_focus, x="split", y="score")
plt.title(f"80-20 training/testing Balance Score focus on latest years (BS >0.5)")
plt.xticks(rotation=90)
plt.show()

for split in df_bs_focus["split"]:
    print_statistics(df_scores, split, f"{split}, BS: {df_bs_focus[df_bs_focus['split'] == split]['score'].iloc[0]}")
# Out:
# ------------------------------------------------------------------
# Report: 2018-05-01 00:00:00, BS: 0.5326287186892528
# 	Training set length: 16957, (25.31%)
# 	Testing set length: 50043, (74.69%)
# 	Num families in training: 510
# 	Num families in testing: 668
# 	Common families: 508
# 	Families in training but not in testing: 2 (0.3%)
# 	Families in testing but not in training: 160 (23.88%)
# ------------------------------------------------------------------
# Report: 2018-06-01 00:00:00, BS: 0.554952320629785
# 	Training set length: 17755, (26.5%)
# 	Testing set length: 49245, (73.5%)
# 	Num families in training: 515
# 	Num families in testing: 668
# 	Common families: 513
# 	Families in training but not in testing: 2 (0.3%)
# 	Families in testing but not in training: 155 (23.13%)
# ------------------------------------------------------------------
# Report: 2018-07-01 00:00:00, BS: 0.5765174930052822
# 	Training set length: 18539, (27.67%)
# 	Testing set length: 48461, (72.33%)
# 	Num families in training: 523
# 	Num families in testing: 668
# 	Common families: 521
# 	Families in training but not in testing: 2 (0.3%)
# 	Families in testing but not in training: 147 (21.94%)
# ------------------------------------------------------------------
# Report: 2018-08-01 00:00:00, BS: 0.6080699217094697
# 	Training set length: 19712, (29.42%)
# 	Testing set length: 47288, (70.58%)
# 	Num families in training: 531
# 	Num families in testing: 668
# 	Common families: 529
# 	Families in training but not in testing: 2 (0.3%)
# 	Families in testing but not in training: 139 (20.75%)
# ------------------------------------------------------------------
# Report: 2018-09-01 00:00:00, BS: 0.6363260310784499
# 	Training set length: 20792, (31.03%)
# 	Testing set length: 46208, (68.97%)
# 	Num families in training: 538
# 	Num families in testing: 668
# 	Common families: 536
# 	Families in training but not in testing: 2 (0.3%)
# 	Families in testing but not in training: 132 (19.7%)
# ------------------------------------------------------------------
# Report: 2018-10-01 00:00:00, BS: 0.6594375931764979
# 	Training set length: 21699, (32.39%)
# 	Testing set length: 45301, (67.61%)
# 	Num families in training: 543
# 	Num families in testing: 667
# 	Common families: 540
# 	Families in training but not in testing: 3 (0.45%)
# 	Families in testing but not in training: 127 (18.96%)
# ------------------------------------------------------------------
# Report: 2018-11-01 00:00:00, BS: 0.6827438423777813
# 	Training set length: 22638, (33.79%)
# 	Testing set length: 44362, (66.21%)
# 	Num families in training: 549
# 	Num families in testing: 666
# 	Common families: 545
# 	Families in training but not in testing: 4 (0.6%)
# 	Families in testing but not in training: 121 (18.06%)
# ------------------------------------------------------------------
# Report: 2018-12-01 00:00:00, BS: 0.7034903978754886
# 	Training set length: 23497, (35.07%)
# 	Testing set length: 43503, (64.93%)
# 	Num families in training: 552
# 	Num families in testing: 664
# 	Common families: 546
# 	Families in training but not in testing: 6 (0.9%)
# 	Families in testing but not in training: 118 (17.61%)
# ------------------------------------------------------------------
# Report: 2019-01-01 00:00:00, BS: 0.7075768979898551
# 	Training set length: 23669, (35.33%)
# 	Testing set length: 43331, (64.67%)
# 	Num families in training: 553
# 	Num families in testing: 662
# 	Common families: 545
# 	Families in training but not in testing: 8 (1.19%)
# 	Families in testing but not in training: 117 (17.46%)
# ------------------------------------------------------------------
# Report: 2019-02-01 00:00:00, BS: 0.7088078468295207
# 	Training set length: 23721, (35.4%)
# 	Testing set length: 43279, (64.6%)
# 	Num families in training: 553
# 	Num families in testing: 661
# 	Common families: 544
# 	Families in training but not in testing: 9 (1.34%)
# 	Families in testing but not in training: 117 (17.46%)
# ------------------------------------------------------------------
# Report: 2019-03-01 00:00:00, BS: 0.7126057274685714
# 	Training set length: 23882, (35.64%)
# 	Testing set length: 43118, (64.36%)
# 	Num families in training: 554
# 	Num families in testing: 661
# 	Common families: 545
# 	Families in training but not in testing: 9 (1.34%)
# 	Families in testing but not in training: 116 (17.31%)
# ------------------------------------------------------------------
# Report: 2019-04-01 00:00:00, BS: 0.7148606777820039
# 	Training set length: 23978, (35.79%)
# 	Testing set length: 43022, (64.21%)
# 	Num families in training: 556
# 	Num families in testing: 661
# 	Common families: 547
# 	Families in training but not in testing: 9 (1.34%)
# 	Families in testing but not in training: 114 (17.01%)
# ------------------------------------------------------------------
# Report: 2019-05-01 00:00:00, BS: 0.7170850299013807
# 	Training set length: 24073, (35.93%)
# 	Testing set length: 42927, (64.07%)
# 	Num families in training: 559
# 	Num families in testing: 660
# 	Common families: 549
# 	Families in training but not in testing: 10 (1.49%)
# 	Families in testing but not in training: 111 (16.57%)
# ------------------------------------------------------------------
# Report: 2019-06-01 00:00:00, BS: 0.7189992914120026
# 	Training set length: 24155, (36.05%)
# 	Testing set length: 42845, (63.95%)
# 	Num families in training: 559
# 	Num families in testing: 660
# 	Common families: 549
# 	Families in training but not in testing: 10 (1.49%)
# 	Families in testing but not in training: 111 (16.57%)
# ------------------------------------------------------------------
# Report: 2019-07-01 00:00:00, BS: 0.7199544344411332
# 	Training set length: 24196, (36.11%)
# 	Testing set length: 42804, (63.89%)
# 	Num families in training: 561
# 	Num families in testing: 660
# 	Common families: 551
# 	Families in training but not in testing: 10 (1.49%)
# 	Families in testing but not in training: 109 (16.27%)
# ------------------------------------------------------------------
# Report: 2019-08-01 00:00:00, BS: 0.7213730429771646
# 	Training set length: 24257, (36.2%)
# 	Testing set length: 42743, (63.8%)
# 	Num families in training: 561
# 	Num families in testing: 660
# 	Common families: 551
# 	Families in training but not in testing: 10 (1.49%)
# 	Families in testing but not in training: 109 (16.27%)
# ------------------------------------------------------------------
# Report: 2019-09-01 00:00:00, BS: 0.723159538789984
# 	Training set length: 24334, (36.32%)
# 	Testing set length: 42666, (63.68%)
# 	Num families in training: 561
# 	Num families in testing: 658
# 	Common families: 549
# 	Families in training but not in testing: 12 (1.79%)
# 	Families in testing but not in training: 109 (16.27%)
# ------------------------------------------------------------------
# Report: 2019-10-01 00:00:00, BS: 0.7247333101920647
# 	Training set length: 24402, (36.42%)
# 	Testing set length: 42598, (63.58%)
# 	Num families in training: 562
# 	Num families in testing: 658
# 	Common families: 550
# 	Families in training but not in testing: 12 (1.79%)
# 	Families in testing but not in training: 108 (16.12%)
# ------------------------------------------------------------------
# Report: 2019-11-01 00:00:00, BS: 0.7275706310879796
# 	Training set length: 24525, (36.6%)
# 	Testing set length: 42475, (63.4%)
# 	Num families in training: 562
# 	Num families in testing: 658
# 	Common families: 550
# 	Families in training but not in testing: 12 (1.79%)
# 	Families in testing but not in training: 108 (16.12%)
# ------------------------------------------------------------------
# Report: 2019-12-01 00:00:00, BS: 0.728329808339563
# 	Training set length: 24558, (36.65%)
# 	Testing set length: 42442, (63.35%)
# 	Num families in training: 562
# 	Num families in testing: 658
# 	Common families: 550
# 	Families in training but not in testing: 12 (1.79%)
# 	Families in testing but not in training: 108 (16.12%)
# ------------------------------------------------------------------
# Report: 2020-01-01 00:00:00, BS: 0.7300978311682719
# 	Training set length: 24635, (36.77%)
# 	Testing set length: 42365, (63.23%)
# 	Num families in training: 562
# 	Num families in testing: 657
# 	Common families: 549
# 	Families in training but not in testing: 13 (1.94%)
# 	Families in testing but not in training: 108 (16.12%)
# ------------------------------------------------------------------
# Report: 2020-02-01 00:00:00, BS: 0.7311975688249973
# 	Training set length: 24683, (36.84%)
# 	Testing set length: 42317, (63.16%)
# 	Num families in training: 562
# 	Num families in testing: 657
# 	Common families: 549
# 	Families in training but not in testing: 13 (1.94%)
# 	Families in testing but not in training: 108 (16.12%)
# ------------------------------------------------------------------
# Report: 2020-03-01 00:00:00, BS: 0.7324782552502423
# 	Training set length: 24739, (36.92%)
# 	Testing set length: 42261, (63.08%)
# 	Num families in training: 563
# 	Num families in testing: 657
# 	Common families: 550
# 	Families in training but not in testing: 13 (1.94%)
# 	Families in testing but not in training: 107 (15.97%)
# ------------------------------------------------------------------
# Report: 2020-04-01 00:00:00, BS: 0.7348499684430982
# 	Training set length: 24843, (37.08%)
# 	Testing set length: 42157, (62.92%)
# 	Num families in training: 565
# 	Num families in testing: 657
# 	Common families: 552
# 	Families in training but not in testing: 13 (1.94%)
# 	Families in testing but not in training: 105 (15.67%)
# ------------------------------------------------------------------
# Report: 2020-05-01 00:00:00, BS: 0.7369861110273445
# 	Training set length: 24937, (37.22%)
# 	Testing set length: 42063, (62.78%)
# 	Num families in training: 570
# 	Num families in testing: 655
# 	Common families: 555
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 100 (14.93%)
# ------------------------------------------------------------------
# Report: 2020-06-01 00:00:00, BS: 0.7388210828190601
# 	Training set length: 25018, (37.34%)
# 	Testing set length: 41982, (62.66%)
# 	Num families in training: 571
# 	Num families in testing: 655
# 	Common families: 556
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 99 (14.78%)
# ------------------------------------------------------------------
# Report: 2020-07-01 00:00:00, BS: 0.7415747924159314
# 	Training set length: 25140, (37.52%)
# 	Testing set length: 41860, (62.48%)
# 	Num families in training: 574
# 	Num families in testing: 655
# 	Common families: 559
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 96 (14.33%)
# ------------------------------------------------------------------
# Report: 2020-08-01 00:00:00, BS: 0.7432616168530105
# 	Training set length: 25215, (37.63%)
# 	Testing set length: 41785, (62.37%)
# 	Num families in training: 574
# 	Num families in testing: 655
# 	Common families: 559
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 96 (14.33%)
# ------------------------------------------------------------------
# Report: 2020-09-01 00:00:00, BS: 0.7443836085947151
# 	Training set length: 25265, (37.71%)
# 	Testing set length: 41735, (62.29%)
# 	Num families in training: 575
# 	Num families in testing: 655
# 	Common families: 560
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 95 (14.18%)
# ------------------------------------------------------------------
# Report: 2020-10-01 00:00:00, BS: 0.7461745291494989
# 	Training set length: 25345, (37.83%)
# 	Testing set length: 41655, (62.17%)
# 	Num families in training: 576
# 	Num families in testing: 655
# 	Common families: 561
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 94 (14.03%)
# ------------------------------------------------------------------
# Report: 2020-11-01 00:00:00, BS: 0.7475588732047501
# 	Training set length: 25407, (37.92%)
# 	Testing set length: 41593, (62.08%)
# 	Num families in training: 576
# 	Num families in testing: 655
# 	Common families: 561
# 	Families in training but not in testing: 15 (2.24%)
# 	Families in testing but not in training: 94 (14.03%)
# ------------------------------------------------------------------
# Report: 2020-12-01 00:00:00, BS: 0.7497850081289876
# 	Training set length: 25507, (38.07%)
# 	Testing set length: 41493, (61.93%)
# 	Num families in training: 580
# 	Num families in testing: 654
# 	Common families: 564
# 	Families in training but not in testing: 16 (2.39%)
# 	Families in testing but not in training: 90 (13.43%)
# ------------------------------------------------------------------
# Report: 2021-01-01 00:00:00, BS: 0.7531307932953549
# 	Training set length: 25658, (38.3%)
# 	Testing set length: 41342, (61.7%)
# 	Num families in training: 580
# 	Num families in testing: 654
# 	Common families: 564
# 	Families in training but not in testing: 16 (2.39%)
# 	Families in testing but not in training: 90 (13.43%)
# ------------------------------------------------------------------
# Report: 2021-02-01 00:00:00, BS: 0.7549618030679969
# 	Training set length: 25741, (38.42%)
# 	Testing set length: 41259, (61.58%)
# 	Num families in training: 580
# 	Num families in testing: 654
# 	Common families: 564
# 	Families in training but not in testing: 16 (2.39%)
# 	Families in testing but not in training: 90 (13.43%)
# ------------------------------------------------------------------
# Report: 2021-03-01 00:00:00, BS: 0.7585409194773218
# 	Training set length: 25904, (38.66%)
# 	Testing set length: 41096, (61.34%)
# 	Num families in training: 584
# 	Num families in testing: 654
# 	Common families: 568
# 	Families in training but not in testing: 16 (2.39%)
# 	Families in testing but not in training: 86 (12.84%)
# ------------------------------------------------------------------
# Report: 2021-04-01 00:00:00, BS: 0.7624022315901555
# 	Training set length: 26081, (38.93%)
# 	Testing set length: 40919, (61.07%)
# 	Num families in training: 584
# 	Num families in testing: 653
# 	Common families: 567
# 	Families in training but not in testing: 17 (2.54%)
# 	Families in testing but not in training: 86 (12.84%)
# ------------------------------------------------------------------
# Report: 2021-05-01 00:00:00, BS: 0.7654160633753685
# 	Training set length: 26220, (39.13%)
# 	Testing set length: 40780, (60.87%)
# 	Num families in training: 584
# 	Num families in testing: 652
# 	Common families: 566
# 	Families in training but not in testing: 18 (2.69%)
# 	Families in testing but not in training: 86 (12.84%)
# ------------------------------------------------------------------
# Report: 2021-06-01 00:00:00, BS: 0.774422950964975
# 	Training set length: 26640, (39.76%)
# 	Testing set length: 40360, (60.24%)
# 	Num families in training: 592
# 	Num families in testing: 651
# 	Common families: 573
# 	Families in training but not in testing: 19 (2.84%)
# 	Families in testing but not in training: 78 (11.64%)
# ------------------------------------------------------------------
# Report: 2021-07-01 00:00:00, BS: 0.7803856600638531
# 	Training set length: 26922, (40.18%)
# 	Testing set length: 40078, (59.82%)
# 	Num families in training: 595
# 	Num families in testing: 650
# 	Common families: 575
# 	Families in training but not in testing: 20 (2.99%)
# 	Families in testing but not in training: 75 (11.19%)
# ------------------------------------------------------------------
# Report: 2021-08-01 00:00:00, BS: 0.7906647884013587
# 	Training set length: 27416, (40.92%)
# 	Testing set length: 39584, (59.08%)
# 	Num families in training: 596
# 	Num families in testing: 650
# 	Common families: 576
# 	Families in training but not in testing: 20 (2.99%)
# 	Families in testing but not in training: 74 (11.04%)
# ------------------------------------------------------------------
# Report: 2021-09-01 00:00:00, BS: 0.9788429077822759
# 	Training set length: 40822, (60.93%)
# 	Testing set length: 26178, (39.07%)
# 	Num families in training: 654
# 	Num families in testing: 636
# 	Common families: 620
# 	Families in training but not in testing: 34 (5.07%)
# 	Families in testing but not in training: 16 (2.39%)
# ------------------------------------------------------------------
# Report: 2021-10-01 00:00:00, BS: 0.9987978578800495
# 	Training set length: 45454, (67.84%)
# 	Testing set length: 21546, (32.16%)
# 	Num families in training: 661
# 	Num families in testing: 616
# 	Common families: 607
# 	Families in training but not in testing: 54 (8.06%)
# 	Families in testing but not in training: 9 (1.34%)
# ------------------------------------------------------------------
# Report: 2021-11-01 00:00:00, BS: 0.9989798994163933
# 	Training set length: 45568, (68.01%)
# 	Testing set length: 21432, (31.99%)
# 	Num families in training: 661
# 	Num families in testing: 613
# 	Common families: 604
# 	Families in training but not in testing: 57 (8.51%)
# 	Families in testing but not in training: 9 (1.34%)
# ------------------------------------------------------------------
# Report: 2021-12-01 00:00:00, BS: 0.9994940780933118
# 	Training set length: 45962, (68.6%)
# 	Testing set length: 21038, (31.4%)
# 	Num families in training: 661
# 	Num families in testing: 611
# 	Common families: 602
# 	Families in training but not in testing: 59 (8.81%)
# 	Families in testing but not in training: 9 (1.34%)
# ------------------------------------------------------------------
# Report: 2022-01-01 00:00:00, BS: 0.7900260109335138
# 	Training set length: 66415, (99.13%)
# 	Testing set length: 585, (0.87%)
# 	Num families in training: 670
# 	Num families in testing: 75
# 	Common families: 75
# 	Families in training but not in testing: 595 (88.81%)
# 	Families in testing but not in training: 0 (0.0%)
# ------------------------------------------------------------------
# Report: 2022-02-01 00:00:00, BS: 0.7890765941048584
# 	Training set length: 66461, (99.2%)
# 	Testing set length: 539, (0.8%)
# 	Num families in training: 670
# 	Num families in testing: 72
# 	Common families: 72
# 	Families in training but not in testing: 598 (89.25%)
# 	Families in testing but not in training: 0 (0.0%)
# ------------------------------------------------------------------
# Report: 2022-03-01 00:00:00, BS: 0.7836128837009272
# 	Training set length: 66724, (99.59%)
# 	Testing set length: 276, (0.41%)
# 	Num families in training: 670
# 	Num families in testing: 56
# 	Common families: 56
# 	Families in training but not in testing: 614 (91.64%)
# 	Families in testing but not in training: 0 (0.0%)

# %% [markdown]
# ## Jensen-Shannon distance and % Appearing families: Considerations
#
# As discussed before, in the last three bins there isn't any new appearing family in the test set.
#
# The drastic increase of Jensen-Shannon distance is due to the fact that lots of families are disappearing e.g. are seen in the training set but not in the testing set.
#
# In 2021-12-01 8.81% of families are seen only on the training set, while 88.81% at 2022-01-01 .
#
# Those three splits are not interesting for studying family drift.

# %%
df_js = pd.DataFrame({"split": date_splits, "score": js_scores})
plt.figure(figsize=(10, 7))
ax = sns.barplot(data=df_js, x="split", y="score")
plt.title("Jensen-Shannon distance between train/test data")
plt.xticks([])
plt.show()

# %%
plt.figure(figsize=(10, 7))
df_af = pd.DataFrame({"split": date_splits, "score": perc_app_families})
ax = sns.barplot(data=df_af, x="split", y="score")
plt.title("% Appearing families in testing set")
plt.xticks([])
plt.show()

# %%
df_bs["label"] = "80-20 Balance score"
df_js["label"] = "Jensen Shannon distance"
df_af["label"] = "% Appearing families"

df_concat_scores = pd.concat([df_bs, df_af])
df_concat_scores = df_concat_scores[df_concat_scores["split"] > t_focus]

plt.figure(figsize=(10, 7))
ax = sns.barplot(data=df_concat_scores, x="split", hue="label", y="score")
plt.title("80-20 Balance Score and % Appearing families: a comparison")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Best split based on 80-20 Training-Test Balance Score and % Appearing families
#
# Using $BS > 0.5$ e.g. 40.18% of the training set length as a basis, the best split is computed using $BS$ + % Appearing families as optimization criteria.

# %%
df_merge_scores = pd.merge(left=df_bs, right=df_af, on="split")
df_merge_scores = df_merge_scores[df_merge_scores["split"] > t_focus]
s_scores = df_merge_scores["score_x"] + df_merge_scores["score_y"]

max_v, max_v_idx = np.max(s_scores), np.argmax(s_scores)
best_split = list(df_merge_scores['split'])[max_v_idx]
print_statistics(df_scores, best_split, best_split)
# Out:
# ------------------------------------------------------------------
# Report: 2021-12-01 00:00:00
# 	Training set length: 45962, (68.6%)
# 	Testing set length: 21038, (31.4%)
# 	Num families in training: 661
# 	Num families in testing: 611
# 	Common families: 602
# 	Families in training but not in testing: 59 (8.81%)
# 	Families in testing but not in training: 9 (1.34%)

# %% [markdown]
# ## Conclusions
#
# Using a Training-Testing Balance score that increases when the training set length is approaching 80% of the overall data + % of appearing families in the test set gives 2021-12-01 as the best split, with new 9 families seen in the testing set.
#
# As described before, there's another time split that is interesting to consider: 2021-09-01.
# The training set here is composed of ~60% of data points (still has a large percentage of samples) and 16 families are appearing in the testing set, as opposed to 9.
#
# This indicates that the Training-Testing balance score isn't much appropriate because it linearly decrease as the percentage deviates from 80%, impacting too much negatively for still quite good splits.
#
# Furthermore, equidistant splits of one day might be considered on later analysis, especially for 2021-08, where a sudden increase of training set length verifies (40.92% to 60.93%).
